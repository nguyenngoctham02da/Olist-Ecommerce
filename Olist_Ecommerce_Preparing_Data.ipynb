# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenngoctham02da/Olist-Ecommerce/blob/main/Olist_Ecommerce_Preparing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Customers

# %%
df_customers = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_customers_dataset.csv",index_col=False)

# %%
df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
print ("1. Basic infomation of the customers dataset: ")
print (df_customers.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the customer dataset: ",df_customers.shape)
print ("-----------------------------------------------------------------")
print("3. Numbers of unique value of customer_id: ",df_customers['customer_id'].nunique())
print ("-----------------------------------------------------------------")
print("4. Numbers of unique value of customer_unique_id: ", df_customers['customer_unique_id'].nunique())
# Out:
# 1. Basic infomation of the customers dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
#  5   new_customer_id           99441 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 4.6+ MB
# None
# -----------------------------------------------------------------
# 2. Number of columns and rows in the customer dataset:  (99441, 6)
# -----------------------------------------------------------------
# 3. Numbers of unique value of customer_id:  99441
# -----------------------------------------------------------------
# ...

# %%
df_customers['new_customer_id'] = ['CS{:02d}'.format(i+1) for i in range(len(df_customers))]

df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
# df_customers.to_csv('Customers.csv', index=False)

# %% [markdown]
# # Geolocation

# %%
df_geolocation = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_geolocation_dataset.csv",index_col=False)

# %%
df_geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
print ("1. Basic infomation of the geolocation dataset: ")
print (df_geolocation.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the geolocation dataset: ",df_geolocation.shape)
print ("-----------------------------------------------------------------")
print("3. Numbers of unique value of zip code ",df_geolocation['geolocation_zip_code_prefix'].nunique())
# Out:
# 1. Basic infomation of the geolocation dataset:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19015 entries, 0 to 999846
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  19015 non-null  int64
#  1   geolocation_city             19015 non-null  object
#  2   geolocation_state            19015 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 594.2+ KB
# None
# -----------------------------------------------------------------
# 2. Number of columns and rows in the geolocation dataset:  (19015, 3)
# -----------------------------------------------------------------
# 3. Numbers of unique value of zip code  19015

# %%
df_geolocation = df_geolocation.drop(columns = ['geolocation_lat', 'geolocation_lng'])

# %%
print("Number of zip_code: ",df_geolocation["geolocation_zip_code_prefix"].nunique())
# Out:
# Number of zip_code:  19015

# %%
df_geolocation = df_geolocation.drop_duplicates(subset=['geolocation_zip_code_prefix'])

# %%
df_geolocation
# Out:
#         geolocation_zip_code_prefix      geolocation_city geolocation_state
# 0                              1037             sao paulo                SP
# 1                              1046             sao paulo                SP
# 3                              1041             sao paulo                SP
# 4                              1035             sao paulo                SP
# 5                              1012             são paulo                SP
# ...                             ...                   ...               ...
# 999774                        99955          vila langaro                RS
# 999780                        99970               ciriaco                RS
# 999786                        99910      floriano peixoto                RS
# 999803                        99920              erebango                RS
# 999846                        99952  santa cecilia do sul                RS
#
# [19015 rows x 3 columns]

# %% [markdown]
# # Order_item

# %%
df_order_items = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_order_items_dataset.csv",index_col=False)

# %%
df_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
print ("1. Basic infomation of the order item dataset: ")
print (df_order_items.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the order item dataset: ",df_order_items.shape)
print ("-----------------------------------------------------------------")
print('3. Number of order_id in order_item dataset :',df_order_items['order_id'].nunique())
print ("-----------------------------------------------------------------")
print('4. Number of product_id in order_item dataset: ',df_order_items['product_id'].nunique())
print ("-----------------------------------------------------------------")
print('5. Number of seller_id in order_item dataset: ',df_order_items['seller_id'].nunique())
# Out:
# 1. Basic infomation of the order item dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB
# None
# -----------------------------------------------------------------
# 2. Number of columns and rows in the order item dataset:  (112650, 7)
# -----------------------------------------------------------------
# 3. Number of order_id in order_item dataset : 98666
# ...

# %% [markdown]
# # Order_payments

# %%
df_order_payments = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_order_payments_dataset.csv",index_col=False)
df_order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
print ("1. Basic infomation of the order payment dataset: ")
print (df_order_payments.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the order payment dataset: ",df_order_payments.shape)
print ("-----------------------------------------------------------------")
print('3. Number of order_id :', df_order_payments['order_id'].nunique())
print ("-----------------------------------------------------------------")
print('4. List of payment method :', df_order_payments['payment_type'].unique())
print ("-----------------------------------------------------------------")
print('5. Number of uses of payment method: ',df_order_payments['payment_type'].value_counts())
# Out:
# 1. Basic infomation of the order payment dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
# None
# -----------------------------------------------------------------
# 2. Number of columns and rows in the order payment dataset:  (103886, 5)
# -----------------------------------------------------------------
# 3. Number of order_id : 99440
# -----------------------------------------------------------------
# ...

# %%
# unique order_id < order records row --> duplicates
# Kiểm tra số duplicate của order_id
print(df_order_payments['order_id'].duplicated().sum())
# Out:
# 4446

# %%
# df_order_payments.groupby('order_id').agg(
#     payment_sequential_count=('payment_sequential', 'count'),
#     payment_value_sum=('payment_value', 'sum'),
#     unique_payment_type=('payment_type', 'nunique')
# ).sort_values('payment_sequential_count', ascending=False).reset_index().head()

# %% [markdown]
# order_id trùng lặp có payment_sequential > 1

# %%
df_order_payments[df_order_payments['payment_installments'] > 1]['payment_type'].value_counts()
# Out:
# credit_card    51338
# Name: payment_type, dtype: int64

# %% [markdown]
# order_id which has more than one payment_installment uses credit card to pay

# %%
# #Tổng Payment_value cho mỗi order_id cùng với Payment_type của chúng. Vì có một số đơn hàng có nhiều loại thanh toán nên vẫn có một số order_id trùng lặp
# df_order_payments = df_order_payments.groupby(['order_id', 'payment_type'])[['payment_value']].sum().reset_index()
# print(df_order_payments['order_id'].duplicated().sum())
# print(df_order_payments.shape)
# df_order_payments

# %% [markdown]
# # Order_reviews

# %%
df_order_reviews = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_order_reviews_dataset.csv",index_col=False)
df_order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
print ("1. Basic infomation of the order review dataset: ")
print (df_order_reviews.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the order review dataset",df_order_reviews.shape)
print ("-----------------------------------------------------------------")
print('3. Number of null values in the order review dataset: ')
print(df_order_reviews.isnull().sum())
print ("-----------------------------------------------------------------")
print('4. List of value of review score: ', df_order_reviews["review_score"].unique()
)
# Out:
# 1. Basic infomation of the order review dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 5.3+ MB
# None
# -----------------------------------------------------------------
# 2. Number of columns and rows in the order review dataset (99224, 7)
# -----------------------------------------------------------------
# ...

# %%
df_order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# # Orders

# %%
df_orders = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_orders_dataset.csv",index_col=False)
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
print ("1. Basic infomation of the order dataset: ")
print (df_orders.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the order dataset",df_orders.shape)
print ("-----------------------------------------------------------------")
print('3. List of order status: ')
print(df_orders['order_status'].unique())
print ("-----------------------------------------------------------------")
print("4. Number of null value in the order dataset")
print(df_orders.isnull().sum())
# Out:
# 1. Basic infomation of the order dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB
# None
# -----------------------------------------------------------------
# ...

# %%
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'])
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'])
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])

# %%
df_orders['order_id'].duplicated().sum()
# Out:
# 0

# %%
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
df_orders.head(20)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5   a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6   136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7   6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8   76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9   e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
# 10  e6ce16cb79ec1d90b1da9085a6118aeb  494dded5b201313c64ed7f100595b95c
# 11  34513ce0c4fab462a55830c0989c7edb  7711cf624183d843aafe81855097bc37
# ...

# %% [markdown]
# # Products

# %%
df_products = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/olist_products_dataset.csv",index_col=False)
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
print ("1. Basic infomation of the product dataset: ")
print (df_products.info())
print ("-----------------------------------------------------------------")
print("2. Number of columns and rows in the product dataset",df_products.shape)
print ("-----------------------------------------------------------------")
print('3. Number of category',df_products['product_category_name'].nunique())
print ("-----------------------------------------------------------------")
print("4. Number of null value in the products dataset")
print(df_products.isnull().sum())
# Out:
# 1. Basic infomation of the product dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
#  9   new_product_id              32951 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 2.5+ MB
# None
# -----------------------------------------------------------------
# ...

# %%
print("Products paremeters")
print ("-----------------------------------------------------------------")
print("Range of length of products: ")
print("Max length is: ",df_products['product_length_cm'].max(), " cm")
print("Min length is: ",df_products['product_length_cm'].min(), " cm")
print ("-----------------------------------------------------------------")
print("Range of weight of products: ")
print("Max weight is: ",df_products['product_weight_g'].max(), " g")
print("Min weight is: ",df_products['product_weight_g'].min(), " g")
print ("-----------------------------------------------------------------")
print("Range of height of products: ")
print("Max height is: ",df_products['product_height_cm'].max(), " cm")
print("Min height is: ",df_products['product_height_cm'].min(), " cm")
print ("-----------------------------------------------------------------")
print("Range of width of products: ")
print("Max width is: ",df_products['product_width_cm'].max(), " cm")
print("Min width is: ",df_products['product_width_cm'].min(), " cm")
# Out:
# Products paremeters
# -----------------------------------------------------------------
# Range of length of products:
# Max length is:  105.0  cm
# Min length is:  7.0  cm
# -----------------------------------------------------------------
# Range of weight of products:
# Max weight is:  40425.0  g
# Min weight is:  0.0  g
# -----------------------------------------------------------------
# Range of height of products:
# Max height is:  105.0  cm
# Min height is:  2.0  cm
# -----------------------------------------------------------------
# Range of width of products:
# Max width is:  118.0  cm
# Min width is:  6.0  cm

# %%
df_products['new_product_id'] = ['PD{:02d}'.format(i+1) for i in range(len(df_products))]

df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# # Product_category_name_translation

# %%
df_product_category_name_translation = pd.read_csv("/content/drive/Shareddrives/Học kỳ 8/Phân tích dữ liệu trong kinh doanh/Dataset/product_category_name_translation.csv",index_col=False)
df_product_category_name_translation
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df_product_category_name_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
